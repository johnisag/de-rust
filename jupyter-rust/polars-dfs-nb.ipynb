// %%
// Cell 1: Declare dependency and create a simple DataFrame
:dep polars = { version = "0.43", features = ["lazy", "dtype-date", "dtype-datetime", "parquet"] }

use polars::prelude::*;

// %%
let df = df! [
    "name" => &["Alice", "Bob"],
    "age" => &[30i64, 25i64],
    "city" => &["NYC", "LA"],
    "food" => &["port", "pizza"]
]?;

println!("{:?}", df);
// Out:
// shape: (2, 4)
// ┌───────┬─────┬──────┬───────┐
// │ name  ┆ age ┆ city ┆ food  │
// │ ---   ┆ --- ┆ ---  ┆ ---   │
// │ str   ┆ i64 ┆ str  ┆ str   │
// ╞═══════╪═════╪══════╪═══════╡
// │ Alice ┆ 30  ┆ NYC  ┆ port  │
// │ Bob   ┆ 25  ┆ LA   ┆ pizza │
// └───────┴─────┴──────┴───────┘

// %%
df
